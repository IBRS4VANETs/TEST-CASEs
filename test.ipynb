# %%
from utils.drawtools import pltbar
diff_cost = [207.9, 438.2, 672.0, 915.2, 1143.0, 1378.2, 1615.5, 1865.0, 2088.1, 2313.5]
# pltpoly(len(diff_cost), [diff_cost], ['cost'], range(10, 101, 10), 'Average computation cost (ms)', 2, 'No. of signatures', 'batch3_poly', show_num=False )
pltbar(len(diff_cost), 12, [diff_cost], ['delta time (ring size=10)'], range(10, 101, 10), 'Computation time (ms)', 2, 'No. of signatures', 'batch3_bar')
